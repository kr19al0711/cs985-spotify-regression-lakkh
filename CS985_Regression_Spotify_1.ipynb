# %% [markdown]
# <a href="https://colab.research.google.com/github/kr19al0711/cs985-spotify-regression-lakkh/blob/main/CS985_Regression_Spotify_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# ...
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

cs_985_6_spotify_regression_problem_2025_path = kagglehub.competition_download('cs-985-6-spotify-regression-problem-2025')

print('Data source import complete.')
# Out:
# ...
# 100%|██████████| 22.1k/22.1k [00:00<00:00, 15.6MB/s]
# Extracting files...
# Data source import complete.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Import training and testing datasets
train_dataset = pd.read_csv(cs_985_6_spotify_regression_problem_2025_path + "/CS98XRegressionTrain.csv")
test_dataset = pd.read_csv(cs_985_6_spotify_regression_problem_2025_path + "/CS98XRegressionTest.csv")

# %%
train_dataset.head()
# Out:
#    Id                                        title            artist  \
# 0   1                                 My Happiness    Connie Francis
# 1   2                             Unchained Melody   The Teddy Bears
# 2   3                        How Deep Is Your Love          Bee Gees
# 3   4                                Woman in Love  Barbra Streisand
# 4   5  Goodbye Yellow Brick Road - Remastered 2014        Elton John
#
#          top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0  adult standards  1996  107    31    45  -8    13   28  150     75     3
# 1              NaN  2011  114    44    53  -8    13   47  139     49     3
# 2  adult standards  1979  105    36    63  -9    13   67  245     11     3
# 3  adult standards  1980  170    28    47 -16    13   33  232     25     3
# 4        glam rock  1973  121    47    56  -8    15   40  193     45     3
#
#    pop
# 0   44
# 1   37
# 2   77
# 3   67
# 4   63
